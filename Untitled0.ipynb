# %% [markdown]
# <a href="https://colab.research.google.com/github/sultanerdin377/QLC-OCEANS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First we create a cell that installs packages we`ll be using
import pandas as pd

# %%
#Start by importing the nutrient data by hand:
data = {
    "Depth_m":[0, 50, 100, 200, 500, 1000, 2000, 4000],
    "Nitrate_Atlantic_uM":[0.5, 1.2, 3.0, 8.5, 18.0, 24.0, 30.0, 32.0],
    "Nitrate_Pacific_uM" : [0.6, 2.0, 6.0, 15.0, 28.0, 36.0, 42.0, 45.0],
}
df = pd.DataFrame(data)

df
# Out:
#    Depth_m  Nitrate_Atlantic_uM  Nitrate_Pacific_uM
# 0        0                  0.5                 0.6
# 1       50                  1.2                 2.0
# 2      100                  3.0                 6.0
# 3      200                  8.5                15.0
# 4      500                 18.0                28.0
# 5     1000                 24.0                36.0
# 6     2000                 30.0                42.0
# 7     4000                 32.0                45.0

# %%
#Plot the data for the Atlantic in a Scatter plot. Make sure the 0 depth is at the top and 4000 m is at the bottom.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['Nitrate_Atlantic_uM'], df['Depth_m'])
plt.xlabel('Nitrate_Atlantic_uM')
plt.ylabel('Depth_m')
plt.title('Nitrate Concentration vs. Depth (Atlantic)')
plt.gca().invert_yaxis() # Invert the y-axis to show 0m at the top
plt.grid(True)
plt.show()

# %%
#Do the same with the Pacific

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
#Now plot a scatter plot in this empty figure
plt.scatter(df['Nitrate_Pacific_uM'], df['Depth_m'])
#Create an x-axis label describing what is on the axis
plt.xlabel('Nitrate_Pacific (uM)')
#Create a y-axis label describing what is on the axis
plt.ylabel('Depth (m)')
#Create a figure tittle
plt.title('Nitrate Profile in the Paciific Ocean')
# Invert y-axis to have 0 at the top
plt.gca().invert_yaxis()
plt.grid(True)
plt.show()

# %%
#Now plot both in the same plot as two separate lines. Include a legend.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.plot(df['Nitrate_Atlantic_uM'], df['Depth_m'], label='Atlantic Ocean')
plt.plot(df['Nitrate_Pacific_uM'], df['Depth_m'], label='Pacific Ocean')
plt.xlabel('Nitrate Concentration (uM)')
plt.ylabel('Depth (m)')
plt.title('Nitrate Concentration vs. Depth in Atlantic and Pacific Oceans)')
plt.gca().invert_yaxis() # Invert the y-axis to show 0m at the top
plt.legend()
plt.grid(True)
plt.show()

# %%
#How do nitrate profiles differ between the Pacific and the Atlantic? Is this consistent with your understanding of nutrient profife? Why
#Both profiles tend to have scarce patterns in shallow waters and increasing almost exponentially as the water deepens near the surface.
#Reflect on this part of the exercise. What worked and what didn`t work? Any frustrations? Anything that was fun or exciting to learn?
#All went good. Particles went good.
